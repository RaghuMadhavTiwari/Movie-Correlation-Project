# %% [markdown]
# <h1 >Correlation in Python

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

pd.set_option("display.max_rows",False)
pd.set_option("display.max_columns",False)

# %%
# Now we need to read in the data
data=pd.read_csv(r"C:\Users\Raghu\Downloads\archive\movies.csv")

# %%
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
data.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# check for nulls
for col in data.columns:
    val=np.mean(data[col].isnull())
    print('{} -{}% nulls'.format(col,round(val*100)))
# Out:
# name -0% nulls
# rating -1% nulls
# genre -0% nulls
# year -0% nulls
# released -0% nulls
# score -0% nulls
# votes -0% nulls
# director -0% nulls
# writer -0% nulls
# star -0% nulls
# country -0% nulls
# budget -28% nulls
# gross -2% nulls
# company -0% nulls
# runtime -0% nulls

# %%
# would not treat nulls as of now
# data types
data.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %%
#removing uneccesary decimals for columns having large numbers
# values did not change cuz of nulls?
for i in ["votes","gross","budget"]:
    data[i]=data[i].astype("int64",errors='ignore')
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# year and release columns years don't match, so we create new year column from released column
data["year_corrected"]=data["released"].astype(str).str[:4]
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
data.sort_values(by="gross",ascending=False,inplace=True)
data.head(20)
# Out:
#                                               name rating      genre  year  \
# 5445                                        Avatar  PG-13     Action  2009
# 7445                             Avengers: Endgame  PG-13     Action  2019
# 3045                                       Titanic  PG-13      Drama  1997
# 6663    Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                        Avengers: Infinity War  PG-13     Action  2018
# 7480                                 The Lion King     PG  Animation  2019
# 6653                                Jurassic World  PG-13     Action  2015
# 6043                                  The Avengers  PG-13     Action  2012
# 6646                                     Furious 7  PG-13     Action  2015
# 7494                                     Frozen II     PG  Animation  2019
# 6644                       Avengers: Age of Ultron  PG-13     Action  2015
# ...

# %% [markdown]
# ### Correlations

# %%
# scatter plot of budget vs gross
plt.scatter(x="budget",y="gross",data=data)
plt.title("Budget vs Gross")
plt.xlabel("Budget")
plt.ylabel("Budget")
# Out:
# Text(0, 0.5, 'Budget')

# %%
# scatter plot of budget vs gross in seaborn will give 
sns.regplot(x="budget",y="gross",data=data,scatter_kws={"color":"pink"},line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#correlation matrix
data.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %% [markdown]
# There are 3 types of methods to calculate correlations
# 1. pearsons(default)
# 2. kendall
# 3. spearman
#
# #### Peason
# Assumption1: Data should be either interval or ratio level
# Assumption2: Linnear relationship between the variables
# Assumption3: No outliers
# Assumption4: Normally Distributed
#
# #### Spearman
# Assumption1: a1 of pearson + ordinal
# Assumption2: Monotonic relationship between variables
# Assumption3: same
# Assumption4: same
#
# #### kendall
# Assumptions are same as spearman
# Kendall is a test of strength of dependece (i.e. one could be written as a linear function of the other)
#
#
# https://ademos.people.uic.edu/Chapter22.html#2_a_brief_overview_of_correlations

# %%
data.corr(method="kendall")
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
data.corr(method="spearman")
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
# heatmap of pearson confusion matrix
confusion_mat=data.corr()
sns.heatmap(confusion_mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
# assigning codes to categorical columns
df_numerized=data
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype=="object"):
        df_numerized[col_name]=df_numerized[col_name].astype("category")
        df_numerized[col_name]=df_numerized[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
# now all columns are numeric, lets look at the confusion matrix :)

confusion_mat=df_numerized.corr()
sns.heatmap(confusion_mat,annot=True)

# do above 2 steps in 1 line for corr matrix 
# df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
# <AxesSubplot:>

# %%
# unstacking the correlation matrix, for easier skimmig of correlated values
CM=df_numerized.corr()
corr_pairs=CM.unstack()
corr_pairs
# Out:
# name            name              1.000000
#                 rating           -0.008069
#                 genre             0.016355
#                 year              0.011453
#                 released         -0.011311
#                 score             0.017097
#                 votes             0.013088
#                 director          0.009079
#                 writer            0.009081
#                 star              0.006472
#                 country          -0.010737
#                 budget            0.023970
#                 gross             0.005533
#                 company           0.009211
#                 runtime           0.010392
#                                     ...
# year_corrected  rating            0.013475
#                 genre             0.028397
#                 year             -0.001562
#                 released          0.993694
#                 score             0.040993
#                 votes             0.017337
# ...

# %%
# see easily which ones are highly correlated
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# genre           budget           -0.356564
# budget          genre            -0.356564
# genre           gross            -0.235650
# gross           genre            -0.235650
# budget          rating           -0.176002
# rating          budget           -0.176002
# votes           genre            -0.145307
# genre           votes            -0.145307
# country         score            -0.133348
# score           country          -0.133348
# rating          gross            -0.107339
# gross           rating           -0.107339
# genre           year             -0.081261
# year            genre            -0.081261
# runtime         country          -0.078412
#                                     ...
# company         company           1.000000
# gross           gross             1.000000
# budget          budget            1.000000
# country         country           1.000000
# star            star              1.000000
# writer          writer            1.000000
# ...

# %%
highly_correlated_pairs=sorted_pairs[(sorted_pairs>0.5)&(sorted_pairs!=1)]
highly_correlated_pairs
# Out:
# votes           gross             0.630757
# gross           votes             0.630757
#                 budget            0.740395
# budget          gross             0.740395
# year_corrected  released          0.993694
# released        year_corrected    0.993694
# dtype: float64
